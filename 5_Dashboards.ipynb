# %% [markdown]
# ## ¿Qué es Dash?
#
# Documentacion oficial: https://dash.plotly.com/?utm_source=chatgpt.com
#
# **Dash** es un framework de Python para crear aplicaciones web interactivas y dashboards. Es especialmente útil para:
#
# - Crear dashboards de datos
# - Aplicaciones web con visualizaciones interactivas
# - Interfaces para análisis de datos
# - Aplicaciones de machine learning
#
# ## ¿Qué es Plotly?
#
# **Plotly** es una biblioteca de visualización que funciona perfectamente con Dash para crear gráficos interactivos y hermosos.
#
# ## Ventajas de usar Dash + Plotly
#
#  **Fácil de aprender** - Solo necesitas Python
#  **Interactividad automática** - Los gráficos son interactivos por defecto
#  **Responsive** - Se adapta a diferentes tamaños de pantalla
#  **Sin JavaScript** - Todo se hace en Python
#  **Integración perfecta** - Dash y Plotly están diseñados para trabajar juntos

# %% [markdown]
# ## Instalación
#
# Primero necesitas instalar las librerías necesarias:
#
# ```bash
# pip install dash plotly pandas
# ```

# %%
# !pip install dash plotly pandas

# %%
# Importar las librerías necesarias
import dash
from dash import dcc, html, Input, Output
import plotly.express as px
import plotly.graph_objects as go
import pandas as pd
import numpy as np

import plotly.io as pio
pio.renderers.default = "notebook"

# %% [markdown]
# ## Conceptos Básicos de Dash
#
# ### 1. Estructura de una App Dash
#
# Una aplicación Dash tiene 3 componentes principales:
#
# 1. **Layout** - Define cómo se ve la aplicación (HTML/CSS)
# 2. **Callbacks** - Define la interactividad (qué pasa cuando el usuario hace algo)
# 3. **App** - La aplicación principal que une todo
#
# ### 2. Componentes Principales
#
# - `html.Div()` - Contenedor básico (como `<div>` en HTML)
# - `dcc.Graph()` - Para mostrar gráficos de Plotly
# - `dcc.Dropdown()` - Menú desplegable
# - `dcc.Slider()` - Control deslizante
# - `html.H1()`, `html.P()` - Títulos y párrafos

# %% [markdown]
# ## Ejemplo 1: Aplicación Básica
#
# Vamos a crear nuestra primera aplicación Dash simple:

# %%
# Crear datos de ejemplo
np.random.seed(42)
data = {
    'x': np.random.randn(100),
    'y': np.random.randn(100),
    'color': np.random.choice(['A', 'B', 'C'], 100)
}

df = pd.DataFrame(data)

# Crear un gráfico con Plotly
fig = px.scatter(df, x='x', y='y', color='color', 
                 title='Mi primer gráfico interactivo',
                 labels={'x': 'Valor X', 'y': 'Valor Y'})

# Crear la aplicación Dash
app = dash.Dash(__name__)

# Definir el layout (cómo se ve la aplicación)
app.layout = html.Div([
    html.H1("Mi Primera App con Dash y Plotly", 
            style={'textAlign': 'center', 'color': '#2E86AB'}),
    
    html.P("Esta es una aplicación simple que muestra un gráfico interactivo",
           style={'textAlign': 'center', 'fontSize': 18}),
    
    dcc.Graph(
        id='mi-grafico',
        figure=fig
    ),
    
    html.P("¡Puedes hacer zoom, moverte por el gráfico y hacer hover sobre los puntos!",
           style={'textAlign': 'center', 'fontStyle': 'italic'})
])

# Para ejecutar la aplicación
app.run(debug=True)
# Out:
#         <iframe
#             width="100%"
#             height="650"
#             src="http://127.0.0.1:8050/"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %% [markdown]
# ## 1. Estructura básica de una app Dash
#
# Una aplicación Dash consta de tres elementos principales:
#
# 1. **Inicialización**: creación del objeto `Dash`.
# 2. **Layout**: definición de la interfaz (componentes, gráficos, texto, etc.).
# 3. **Callbacks**: lógica de interacción (cómo cambia la interfaz según la entrada del usuario).
#
# Ejemplo mínimo:
# ```python
# import dash
# from dash import html
#
# app = dash.Dash(__name__)
#
# # Layout: lo que el usuario verá
# app.layout = html.Div([
#     html.H1("Hola Dash"),
#     html.P("Mi primera aplicación con Dash")
# ])
#
# if __name__ == "__main__":
#     app.run_server(debug=True)
# ```
#
# ---
#
# ## 2. Componentes principales
# Dash ofrece varios componentes en los módulos `dash.html` y `dash.dcc`.
#
# ### 2.1 dash.html
# Permite crear etiquetas HTML nativas:
# - `html.Div`, `html.H1`, `html.P`, `html.Button`, etc.
#
# ### 2.2 dash.dcc (Dash Core Components)
# Incluye elementos interactivos:
# - `dcc.Graph`: para insertar gráficos de Plotly.
# - `dcc.Input`, `dcc.Slider`, `dcc.Dropdown`: para entrada de datos.
# - `dcc.Tabs`, `dcc.Checklist`: para organizar opciones.
#
# Ejemplo con gráfico:
# ```python
# import dash
# from dash import html, dcc
# import plotly.express as px
# import pandas as pd
#
# # Dataset
# df = px.data.iris()
#
# app = dash.Dash(__name__)
#
# app.layout = html.Div([
#     html.H1("Ejemplo: Gráfico con Dash y Plotly"),
#     dcc.Graph(
#         id="grafico-iris",
#         figure=px.scatter(df, x="sepal_width", y="sepal_length", color="species")
#     )
# ])
#
# if __name__ == "__main__":
#     app.run_server(debug=True)
# ```
#
# ---
#
# ## 3. Callbacks (interactividad)
# Los **callbacks** permiten que los componentes reaccionen a la interacción del usuario.
#
# Ejemplo: cambiar el gráfico según la especie seleccionada en un dropdown.
#
# ```python
# from dash import Input, Output
#
# app.layout = html.Div([
#     html.H1("Filtrar especie"),
#     dcc.Dropdown(
#         id="dropdown-especie",
#         options=[{"label": sp, "value": sp} for sp in df["species"].unique()],
#         value="setosa"
#     ),
#     dcc.Graph(id="grafico-filtrado")
# ])
#
# @app.callback(
#     Output("grafico-filtrado", "figure"),
#     Input("dropdown-especie", "value")
# )
# def actualizar_grafico(especie):
#     df_filtrado = df[df["species"] == especie]
#     fig = px.scatter(df_filtrado, x="sepal_width", y="sepal_length", color="species")
#     return fig
# ```
#
# ---
#
# ## 5. Ejercicios
# 1. Crear un dashboard que muestre:
#    - Un gráfico de barras de ventas por categoría.
#    - Un dropdown para seleccionar el año y actualizar el gráfico.
# 2. Implementar un slider que cambie el número de bins de un histograma de precios.
# 3. Construir una app con dos pestañas:
#    - Tab 1: Gráfico de dispersión interactivo.
#    - Tab 2: Gráfico de líneas con rango de fechas.
# 4. Hacer que al dar clic en un punto de un gráfico, aparezcan detalles en una tabla.
